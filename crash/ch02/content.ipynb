# %% [markdown]
# ### 第二章 变量和简单的数据类型

# %% [markdown]
# 2.1 执行python文件中的print函数

# %%
print("hello, python world")
# Out:
# hello, python world

# %% [markdown]
# 2.2 使用变量存储数据

# %%
s = "hello, python world"
print(s)
# Out:
# hello, python world

# %% [markdown]
# 2.3 关于字符串
#
# 1. 单引号' 和双引号" 成对使用，都可以表示字符串字面量，为了可以在其内部不使用转义字符来表示对方
# 2. 字符串常用函数：title()、lstrip()、rstrip()、strip()
# 3. 使用加号连接字符串

# %%
message = "He's book is very interesting, and i love it. "
print(message)
message, message.rstrip()
# Out:
# He's book is very interesting, and i love it.
# ("He's book is very interesting, and i love it. ",
#  "He's book is very interesting, and i love it.")

# %% [markdown]
# 2.4 数字
#
# 1. 整数
# 2. 浮点数：带小数点的数
# 3. 数的运算：加（+），减（-），乘（*），除（/），乘方（**），（整除（//）, 取余（%）

# %%
a, b = 3, 4

(a+b, a-b, a*b, a/b, a**b,  a//b, a%b)
# Out:
# (7, -1, 12, 0.75, 81, 0, 3)
