# %%
# 9-1 9-4

class Restaurant:
    
    def __init__(self, name, type):
        self.restaurant_name = name
        self.cuisine_type = type
        self.number_served = 0
    
    def describe_restaurant(self):
        print(self.restaurant_name)
        print(self.cuisine_type)
    
    def open_restaurant(self):
        print("opening")

    def set_number_served(self, number):
        self.number_served = number
    
    def increment_number_served(self, number):
        print("may be the number served will be " + number)
        self.number_served += 1

restaurant = Restaurant("一笼鲜", "包子店")
restaurant.describe_restaurant()
restaurant.open_restaurant()
print(restaurant.number_served)
restaurant.set_number_served(3)
print(restaurant.number_served)
# Out:
# 一笼鲜
# 包子店
# opening
# 0
# 3

# %%
# 9-6 继承餐馆

class IceCreamStand(Restaurant):
    def __init__(self, flavors):
        super.__init__(self)
        self.flavors = flavors
    
    def describe_flavors():
        for i in self.flavors:
            print(i)

ice = IceCreamStand(restaurant, ['orange', 'apple'])
ice.describe_flavors()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       9         for i in self.flavors:
#      10             print(i)
# ---> 12 ice = IceCreamStand(restaurant, ['orange', 'apple'])
#      13 ice.describe_flavors()
#
# TypeError: IceCreamStand.__init__() takes 2 positional arguments but 3 were given
