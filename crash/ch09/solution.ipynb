# %%
# 9-1 9-4

class Restaurant:
    
    def __init__(self, name, type):
        self.restaurant_name = name
        self.cuisine_type = type
        self.number_served = 0
    
    def describe_restaurant(self):
        print(self.restaurant_name)
        print(self.cuisine_type)
    
    def open_restaurant(self):
        print("opening")

    def set_number_served(self, number):
        self.number_served = number
    
    def increment_number_served(self, number):
        print("may be the number served will be " + number)
        self.number_served += 1

restaurant = Restaurant("一笼鲜", "包子店")
restaurant.describe_restaurant()
restaurant.open_restaurant()
print(restaurant.number_served)
restaurant.set_number_served(3)
print(restaurant.number_served)
# Out:
# 一笼鲜
# 包子店
# opening
# 0
# 3

# %%
# 9-6 继承餐馆

class IceCreamStand(Restaurant):
    def __init__(self, name, type, flavors):
        super().__init__(name, type)
        self.flavors = [i for i in flavors]
    
    def describe_flavors(self):
        for i in self.flavors:
            print(i)
print(restaurant)
ice = IceCreamStand("ice", "sweet", ['orange', 'apple'])
ice.describe_flavors()
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 12
#      10             print(i)
#      11 print(restaurant)
# ---> 12 ice = IceCreamStand("ice", "sweet", ['orange', 'apple'])
#      13 ice.describe_flavors()
#
# Cell In[10], line 5, in IceCreamStand.__init__(self, name, type, flavors)
#       4 def __init__(self, name, type, flavors):
# ----> 5     super.__init__(name, type)
#       6     self.flavors = [i for i in flavors]
#
# TypeError: descriptor '__init__' requires a 'super' object but received a 'str'
